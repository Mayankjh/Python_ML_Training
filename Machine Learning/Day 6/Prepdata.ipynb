# %%
import numpy as np
import pandas as pd
data = pd.read_csv('PrepData.csv')
data
# Out:
#                   NAME  PERCENTAGE  BACKLOG  INTERNSHIP  FIRSTROUND  \
# 0          Apaar Gupta          99        0           3          90
# 1        Aastha Khanna          92        0           3          68
# 2          Yogita Rana          84        3           2          69
# 3                 Kush          67        2           2          23
# 4        Pulkit Mittal          57        0           2          78
# 5       Gaurav Gambhir          85        0           1          86
# 6           Shruti Jha          82        0           3          61
# 7    Ayush Vishwakarma          47        0           2          32
# 8            Divyanshu          62        2           1          56
# 9               Ashish          67        1           0          45
# 10            Jigyasha          56        4           2          78
# 11               Mehar          68        2           1          23
# 12       Arushi Bhalla          65        2           3          90
# ...

# %%
features = list(data.columns[1:6])
features
# Out:
# ['PERCENTAGE', 'BACKLOG', 'INTERNSHIP', 'FIRSTROUND', 'COMMUNICATIONSKILLLS']

# %%
from sklearn import tree
y = data["Hired"]
X = data[features]
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X,y)

# %%
from IPython.display import Image
from sklearn.externals.six import StringIO
import pydotplus

dot_data = StringIO()
tree.export_graphviz(clf,out_file,frature_names = features)
graph = pydotplus.graph_from_dot_data(data_data.getvalue())
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-12385cad5a28> in <module>()
#       4
#       5 dot_data = StringIO()
# ----> 6 tree.export_graphviz(clf,out_file,frature_names = features)
#       7 graph = pydotplus.graph_from_dot_data(data_data.getvalue())
#       8 Image(graph.create_png())
#
# NameError: name 'out_file' is not defined

# %%
from sklearn.ensemble import RandomForestClassifier
clf2 = RandomForestClassifier(n_estimators=10)
clf2 = clf2.fit(X,y)

# Predict employment of an employed 10-year vateran
print(clf2.predict([[99,0,3,90,100]]))

#.....and an unployed 10-year vateran
print(clf2.predict([[62,2,1,56,60]]))
# Out:
# [1]
# [1]
