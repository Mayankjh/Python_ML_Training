# %%
import numpy as np
import pandas as pd
data = pd.read_csv('PastHires.csv')
data
# Out:
#     Years Experience Employed?  Previous employers Level of Education  \
# 0                 10         Y                   4                 BS
# 1                  0         N                   0                 BS
# 2                  7         N                   6                 BS
# 3                  2         Y                   1                 MS
# 4                 20         N                   2                PhD
# 5                  0         N                   0                PhD
# 6                  5         Y                   2                 MS
# 7                  3         N                   1                 BS
# 8                 15         Y                   5                 BS
# 9                  0         N                   0                 BS
# 10                 1         N                   1                PhD
# 11                 4         Y                   1                 BS
# ...

# %%
data.replace({'Employed?':{'Y':0,'N':1},'Top-tier school':{'Y':0,'N':1},'Level of Education':{'BS':0,'MS':1,'PhD':2},'Interned':{'Y':0,'N':1},'Hired':{'Y':0,'N':1}},inplace=True)
data
# Out:
#     Years Experience  Employed?  Previous employers  Level of Education  \
# 0                 10          0                   4                   0
# 1                  0          1                   0                   0
# 2                  7          1                   6                   0
# 3                  2          0                   1                   1
# 4                 20          1                   2                   2
# 5                  0          1                   0                   2
# 6                  5          0                   2                   1
# 7                  3          1                   1                   0
# 8                 15          0                   5                   0
# 9                  0          1                   0                   0
# 10                 1          1                   1                   2
# 11                 4          0                   1                   0
# ...

# %%
features = list(data.columns[:6])
features
# Out:
# ['Years Experience',
#  'Employed?',
#  'Previous employers',
#  'Level of Education',
#  'Top-tier school',
#  'Interned']

# %%
from sklearn import tree
y = data["Hired"]
X = data[features]
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X,y)

# %%
from IPython.display import Image
from sklearn.externals.six import StringIO
import pydotplus

dot_data = StringIO()
tree.export_graphviz(clf,out_file,frature_names = features)
graph = pydotplus.graph_from_dot_data(data_data.getvalue())
Image(graph.create_png())

# %%
from sklearn.ensemble import RandomForestClassifier
clf2 = RandomForestClassifier(n_estimators=10)
clf2 = clf2.fit(X,y)

# Predict employment of an employed 10-year vateran
print(clf2.predict([[10,1,2,0,1,0]]))

#.....and an unployed 10-year vateran
print(clf2.predict([[0,1,4,2,0,0]]))
